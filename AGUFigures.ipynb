# %%
import os
import glob

import functools
import numpy as np
import xarray as xr
import matplotlib
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd

import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client

from fates_calibration.train_emulators import get_pft_grids, get_pft_ensemble
from fates_calibration.FATES_calibration_constants import VAR_UNITS, FATES_INDEX, FATES_PFT_IDS, FATES_INDEX_new

# %%
def get_map(ds, da):
    
    thedir  = '/glade/u/home/forrest/ppe_representativeness/output_v4/'
    thefile = 'clusters.clm51_PPEn02ctsm51d021_2deg_GSWP3V1_leafbiomassesai_PPE3_hist.annual+sd.400.nc'
    sg = xr.open_dataset(thedir+thefile)
    
    out = np.zeros(sg.cclass.shape) + np.nan
    for c,(o,a) in enumerate(sg.rcent_coords):
        i = np.arange(400)[
            (abs(ds.grid1d_lat - a) < 0.1) &
            (abs(ds.grid1d_lon - o) < 0.1)]
        out[sg.cclass == c + 1] = i
    cclass = out.copy()
    cclass[np.isnan(out)] = 0

    sgmap = xr.Dataset()
    sgmap['cclass'] = xr.DataArray(cclass.astype(int), dims=['lat','lon'])
    sgmap['notnan'] = xr.DataArray(~np.isnan(out), dims=['lat','lon'])
    sgmap['lat'] = sg.lat
    sgmap['lon'] = sg.lon
    
    damap = da.sel(gridcell=sgmap.cclass).where(sgmap.notnan).compute()
    
    return damap

def annual_mean(da, cf):

    days_per_month = da['time.daysinmonth']
    ann_mean = cf*(days_per_month*da).groupby('time.year').sum()
    ann_mean.name = da.name

    return ann_mean

def get_colors():
    tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
    for i in range(len(tableau20)):
        r, g, b = tableau20[i]
        tableau20[i] = (r/255., g/255., b/255.)

    return tableau20

def get_minmax_ens(oaat_file, suffix, parameter):
    
    sub = oaat_file[oaat_file.parameter == parameter]
    min_ens = str(sub[sub.minmax == 'min'].ensemble.values[0]).replace(suffix, '')
    max_ens = str(sub[sub.minmax == 'max'].ensemble.values[0]).replace(suffix, '')

    if suffix == 'FATES_OAAT_':
        min_ens = str(min_ens).zfill(3)
        max_ens = str(max_ens).zfill(3)
    
    return min_ens, max_ens

def get_min_max_diff(hist_dir, ensemble_dir, oaat_file, suffix, file_suffix, parameter, variable, cf):

    min_ens, max_ens = get_minmax_ens(oaat_file, suffix, parameter)

    min_file = f'{file_suffix}{min_ens}.nc'
    max_file = f'{file_suffix}{max_ens}.nc'
    
    dataset_min = xr.open_dataset(os.path.join(hist_dir, ensemble_dir, min_file))
    dataset_max = xr.open_dataset(os.path.join(hist_dir, ensemble_dir, max_file))
    
    dat_min = dataset_min[variable]
    dat_max = dataset_max[variable]
    mean_da_min = annual_mean(dat_min, cf).mean(dim='year')
    mean_da_max = annual_mean(dat_max, cf).mean(dim='year')
    
    da_map_min = get_map(dataset_min, mean_da_min)
    da_map_max = get_map(dataset_max, mean_da_max)
    da_diff = da_map_max - da_map_min

    return da_diff.to_dataset(name=variable)

# %%
def get_pft_ensemble(land_mask_file, mesh_file, pfts, ensemble, fates_ind):
    
    pft_ensembles = []
    for pft in pfts:
        pft_grids = get_pft_grids(land_mask_file, mesh_file, fates_ind[pft])
        pft_ensembles.append(ensemble.where(ensemble.gridcell.isin(pft_grids)))
    pft_ensemble = xr.concat(pft_ensembles, dim='pft')

    return pft_ensemble

def plot_pft_ensemble(pft_ensemble, pfts):

    colors = get_colors()
    plt.subplots(figsize=(7, 7), layout='compressed')
    for idx, pft in enumerate(pfts):
        dat = pft_ensemble.isel(pft=idx)
        plt.scatter(dat.GPP, dat.EFLX_LH_TOT, label=pfts[idx], color=colors[idx])
    plt.ylabel('Annual Mean Latent Heat Flux (W/m2)', fontsize=11)
    plt.xlabel('Annual Mean GPP (kgC/m2/yr)', fontsize=11)
    plt.legend(loc='lower right')

# %%
def plot_hist_and_scatter(pft, pft_ensemble_gs0, pft_ensemble_gs1, xvar, yvar, xlab, ylab):
    
    gs0_col = '#298c8c'
    gs1_col = '#800074'

    dat_gs0 = pft_ensemble_gs0.sel(pft=pft).mean(dim='gridcell')
    dat_gs1 = pft_ensemble_gs1.sel(pft=pft).mean(dim='gridcell')
    dat_gs1 = dat_gs1.where(dat_gs1.BTRANMN > 0.0)

    fig = plt.figure(figsize=(6, 6))
    gs = fig.add_gridspec(2, 2,  width_ratios=(4, 1), height_ratios=(1, 4),
                          left=0.1, right=0.9, bottom=0.1, top=0.9,
                          wspace=0.05, hspace=0.05)
    
    ax = fig.add_subplot(gs[1, 0])

    ax_histx = fig.add_subplot(gs[0, 0], sharex=ax)
    ax_histy = fig.add_subplot(gs[1, 1], sharey=ax)
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    ax.scatter(dat_gs1[xvar], dat_gs1[yvar], label='gs1', color=gs1_col, alpha=0.3)
    ax.scatter(dat_gs0[xvar], dat_gs0[yvar], label='gs0', color=gs0_col, alpha=0.3)

    ax_histx.hist(dat_gs0[xvar].values.flatten(), color=gs0_col, alpha=0.5)
    ax_histx.hist(dat_gs1[xvar].values.flatten(), color=gs1_col, alpha=0.5)
    
    ax_histy.hist(dat_gs0[yvar].values.flatten(), color=gs0_col, alpha=0.5, orientation='horizontal')
    ax_histy.hist(dat_gs1[yvar].values.flatten(), color=gs1_col, alpha=0.5, orientation='horizontal')
    
    ax.legend(loc='upper right')
    ax_histx.set_title(dom_pfts[pft].replace('_', ' '))
    ax.set_xlabel(xlab, labelpad=5)
    ax.set_ylabel(ylab, labelpad=5, rotation=90);

# %%
def plot_effect(dat, parameter, variable, units):

    minval = abs(dat[variable].min())
    maxval = abs(dat[variable].max())
    vmax = np.max([minval, maxval])
    
    figure, ax = plt.subplots(1, 1, figsize=(13, 6),
                            subplot_kw=dict(projection=ccrs.Robinson()),
                            layout='compressed')
    ax.set_title(f"Effect of {parameter.replace('fates_', '')} on {variable}", loc='left', fontsize='large', fontweight='bold')
    ax.coastlines()
    ocean = ax.add_feature(cfeature.NaturalEarthFeature('physical', 'ocean', '110m',
                                                        facecolor='white'))
    pcm = ax.pcolormesh(dat.lon, dat.lat, dat[variable],
                        transform=ccrs.PlateCarree(), shading='auto',
                        cmap='RdBu', vmin=-1.0*vmax, vmax=vmax)
    cbar = figure.colorbar(pcm, ax=ax, shrink=0.5, orientation='horizontal')
    cbar.set_label(f'{variable} Difference ({units})', size=10, fontweight='bold')

# %%
mesh_dir = '/glade/work/afoster/FATES_calibration/mesh_files/'

# %%
ensemble_gs1 = xr.open_dataset('/glade/work/afoster/FATES_calibration/history_files/fates_lh_dominant_gs1.nc')

# %%
ensemble_gs0 = xr.open_dataset('/glade/work/afoster/FATES_calibration/history_files/fates_lh_dominant_gso_vcmax.nc')

# %%
dom_pfts = ['broadleaf_evergreen_tropical_tree', 'needleleaf_evergreen_extratrop_tree',
            'needleleaf_colddecid_extratrop_tree', 'arctic_c3_grass', 'cool_c3_grass',
            'c4_grass']

# %%
pft_ensemble_gs1 = get_pft_ensemble(os.path.join(mesh_dir, 'dominant_pft_grid_update.nc'),
                                    os.path.join(mesh_dir, 'dominant_pft_grid_update_mesh.nc'),
                                    dom_pfts, ensemble_gs1, FATES_INDEX_new)

# %%
pft_ensemble_gs0 = get_pft_ensemble(os.path.join(mesh_dir, 'dominant_pft_grid_update.nc'),
                                    os.path.join(mesh_dir, 'dominant_pft_grid_update_mesh.nc'),
                                    dom_pfts, ensemble_gs0, FATES_INDEX_new)

# %%
pft_grids = get_pft_grids(os.path.join(mesh_dir, 'dominant_pft_grid_update.nc'),
                          os.path.join(mesh_dir, 'dominant_pft_grid_update_mesh.nc'), FATES_INDEX_new['needleleaf_colddecid_extratrop_tree'])

# %%
plot_hist_and_scatter(0, pft_ensemble_gs0, pft_ensemble_gs1,
                      'BTRANMN', 'GPP', 'Mean BTRAN', 'Annual GPP (kgC m$^{-2}$ yr$^{-1}$)')
plt.savefig('/glade/u/home/afoster/FATES_Calibration/AGU_figures/BTRAN_GPP_BETT.png')

# %%
# Setup PBSCluster
cluster = PBSCluster(
    cores=1,                                                   # The number of cores you want
    memory='25GB',                                             # Amount of memory
    processes=1,                                               # How many processes
    queue='casper',                                            # The type of queue to utilize
    local_directory='/glade/work/afoster',                     # Use your local directory
    resource_spec='select=1:ncpus=1:mem=25GB',                 # Specify resources
    log_directory='/glade/derecho/scratch/afoster/dask_logs',  # log directory
    account='P93300041',                                       # Input your project ID here
    walltime='02:00:00',                                       # Amount of wall time
    interface='ext')                                           # Interface to use

cluster.scale(30)
dask.config.set({
    'distributed.dashboard.link': 'https://jupyterhub.hpc.ucar.edu/stable/user/{USER}/proxy/{port}/status'
})
client = Client(cluster)
client
# Out:
# /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 36751 instead
#   warnings.warn(
# <Client: 'tcp://128.117.208.81:35481' processes=0 threads=0, memory=0 B>
# Task exception was never retrieved
# future: <Task finished name='Task-158641' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158346' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158647' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158651' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158654' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158657' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158664' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158668' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158673' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158680' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158684' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158688' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158690' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158697' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158699' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158702' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158704' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158708' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158710' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158718' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158723' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158731' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158734' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158740' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158743' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158758' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158762' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158766' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158769' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158772' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158778' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158785' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158793' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158798' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158808' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158811' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158814' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158815' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158818' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158822' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158826' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158827' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158833' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158838' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158840' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158848' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158853' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158855' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158859' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158860' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158865' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158866' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158870' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158872' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158875' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158880' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158882' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158888' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158893' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158897' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158899' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158906' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158914' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158922' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158924' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158929' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158932' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158935' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158939' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158941' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158947' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158953' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158957' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158960' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158964' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158968' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158976' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158979' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158981' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158985' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158986' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158990' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158993' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158995' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158999' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159004' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159009' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159012' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159013' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159018' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159021' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159027' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159031' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159035' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159039' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159040' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159045' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-159048' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158417' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158420' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158423' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158427' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
# ...
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158176' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158179' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158183' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158185' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158188' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158190' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158192' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158194' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158199' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158200' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158203' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158206' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158209' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158210' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158213' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158215' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158217' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158218' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158220' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158222' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158227' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158228' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158233' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158234' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158236' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158243' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158247' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158248' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158252' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158255' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158257' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158259' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158270' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-158276' coro=<Client._gather.<locals>.wait() done, defined at /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
hist_dir_gs1 = '/glade/work/afoster/FATES_calibration/history_files/fates_lh_dominant_gs1'
files_gs1 = sorted([os.path.join(hist_dir_gs1, file) for file in os.listdir(hist_dir_gs1)])

hist_dir_gs0 = '/glade/work/afoster/FATES_calibration/history_files/fates_lh_dominant_gso_vcmax'
files_gs0 = sorted([os.path.join(hist_dir_gs0, file) for file in os.listdir(hist_dir_gs0)])

# %%
ds_gs1 = xr.open_mfdataset(files_gs1, combine='nested', concat_dim='ensemble', parallel=True)
sub_gs1 = ds_gs1.isel(gridcell=364)

# %%
#sub_gs1['GPP_month'] = 24*60*60*(ds_gs1['time.daysinmonth']*sub_gs1.GPP)
sub_gs1['GPP_month'] = sub_gs1.GPP/1E-6/12.011*1000.0
sub_gs1['WUE'] = sub_gs1['GPP_month']/sub_gs1.EFLX_LH_TOT.where(sub_gs1.EFLX_LH_TOT > 0)

# %%
wue=sub_gs1.WUE.to_dataset(name='WUE')

# %%
wue.to_netcdf('/glade/work/afoster/FATES_calibration/history_files/gs1_sub.nc')

# %%
ds_gs0 = xr.open_mfdataset(files_gs0, combine='nested', concat_dim='ensemble', parallel=True)
sub_gs0 = ds_gs0.isel(gridcell=364)

# %%
sub_gs0['GPP_month'] = sub_gs0.GPP/1E-6/12.011*1000.0
sub_gs0['WUE'] = sub_gs0['GPP_month']/sub_gs0.EFLX_LH_TOT.where(sub_gs0.EFLX_LH_TOT > 0)

# %%
wue=sub_gs0.WUE.to_dataset(name='WUE')

# %%
sub_gs0.grid1d_lat.isel(ensemble=1).values
# Out:
# array(59.68421053)

# %%
sub_gs0.grid1d_lon.isel(ensemble=1).values
# Out:
# array(135.)

# %%
wue.to_netcdf('/glade/work/afoster/FATES_calibration/history_files/gs0_sub.nc')
# Out:
# /glade/work/afoster/conda-envs/fates_calibration/lib/python3.11/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 47.27 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
gs1_mean = sub_gs1.isel(ensemble=slice(1, 501)).WUE.mean(dim='ensemble')
gs0_mean = sub_gs0.isel(ensemble=slice(1, 501)).WUE.mean(dim='ensemble')

# %%
time = sub_gs0.time

# %%
plt.plot(time, gs1_mean, color=gs1_col, label='gs1')
plt.plot(time, gs0_mean, color=gs0_col, label='gs0')

# %%
fig = plt.figure(figsize=(12, 12))
quantiles = [1, 5, 25]
colors = [0.9, 0.7, 0.5]
labels = ['1st-99th percentile', '5th-95th percentile', '25th-75th percentile']

for i, quantile in enumerate(quantiles):
    q1 = sub_gs1.WUE.isel(ensemble=slice(1, 501)).chunk(dict(ensemble=-1, time=-1)).quantile(quantile/100, dim='ensemble')
    q2 = sub_gs1.WUE.isel(ensemble=slice(1, 501)).chunk(dict(ensemble=-1, time=-1)).quantile(1 - quantile/100, dim='ensemble')
    plt.fill_between(time, q1, q2, color=colors[i]*np.ones(3), label=labels[i])

# %%
client.shutdown()

# %%
clm_oaat = pd.read_csv('/glade/work/afoster/FATES_calibration/parameter_files/clm6sp_oaat.csv', header=None)
clm_oaat.columns = ['ensemble', 'parameter', 'minmax']
fates_oaat = pd.read_csv('/glade/work/afoster/FATES_calibration/parameter_files/fates_param_oaat/fates_oaat_key.csv', index_col=[0])
fates_oaat.columns = ['ensemble', 'minmax', 'parameter']

# %%
hist_dir = '/glade/work/afoster/FATES_calibration/history_files'

clm_hydro_ensemble_dir = 'ctsm_sp_oaat'
clm_hydro_suffix = 'ctsm60SP_bigleaf_sparsegrid_CLM6SPoaat'

clm_btran_ensemble_dir = 'ctsm_sp_oaat_btran'
clm_btran_suffix = 'ctsm60SP_bigleaf_sparsegrid_btran_CLM6SPoaat'

fates_clm_ensemble_dir = 'fates_clmpars_sp_oaat'
fates_clm_suffix = 'ctsm60SP_fates_sparsegrid_CLM6SPoaat'

fates_ensemble_dir = 'fates_sp_oaat'
fates_suffix = 'ctsm60SP_fates_sparsegrid_FATES_OAAT_'

# %%
fates_param = 'smpsc_delta'
fates_btran = get_min_max_diff(hist_dir, fates_ensemble_dir, fates_oaat,
                             'FATES_OAAT_', fates_suffix, fates_param, 'BTRANMN', 1/365)

# %%
plot_effect(fates_btran, fates_param, 'BTRANMN', '')
#plt.savefig('/glade/u/home/afoster/FATES_Calibration/AGU_figures/gpp_rad_leaf_clumping.png', dpi=300)

# %%
param = 'fff'
fates_btran_fff = get_min_max_diff(hist_dir, fates_clm_ensemble_dir, clm_oaat,
                             'CLM6SPoaat', fates_clm_suffix, param, 'BTRANMN', 1/365)
plot_effect(fates_btran_fff, param, 'BTRANMN', '')

# %%
param = 'smpso'
clm_btran_fff = get_min_max_diff(hist_dir, clm_btran_ensemble_dir, clm_oaat,
                             'CLM6SPoaat', clm_btran_suffix, param, 'BTRANMN', 1/365)
plot_effect(clm_btran_fff, param, 'BTRANMN', '')
